# %%
import random
import json
import gym
from gym import spaces
import pandas as pd
import numpy as np

# %%
states can be the  number of stocks owned, current stock price and account balanceeg [20, 230, 1500]
dealind gwith POMDP so we dont know what the reward function or transition probability looks like so we use
q-learning to lean these two.

# %%
df = pd.read_csv(r"C:\Users\eyalt\Downloads\btc_6H_C.csv")
df.head(10)
# Out:
#              Timestamp    Open    High     Low   Close  Volume_(BTC)  \
# 0  2015-01-14 00:00:00  227.01  230.89  213.32  213.42   6823.048857
# 1  2015-01-14 06:00:00  213.32  215.00  152.40  190.65  55956.799331
# 2  2015-01-14 12:00:00  190.62  208.11  175.71  176.35  32111.532855
# 3  2015-01-14 18:00:00  176.00  186.58  161.10  171.41  29297.504040
# 4  2015-01-15 00:00:00  172.00  205.56  168.50  193.08  17490.653370
# 5  2015-01-15 06:00:00  193.07  214.90  190.60  212.17  16747.220908
# 6  2015-01-15 12:00:00  212.13  233.90  209.25  217.89  28248.512378
# 7  2015-01-15 18:00:00  217.01  224.00  192.00  210.98  21002.029530
# 8  2015-01-16 00:00:00  210.69  222.47  206.00  216.90   7145.633561
# 9  2015-01-16 06:00:00  216.50  223.15  210.40  216.44   8101.936378
#
#    Volume_(Currency)  Weighted_Price       MACD   MACD_Sig  MACD_status  \
# 0       1.495162e+06      219.366758 -17.876382 -12.636517          0.5
# ...

# %%
class TradingEnv(gym.Env):
    """Single stock trading environment"""
    
    def __init__(self, df):
        self.df = df
        self.reward_range = (0, max_acc_bal)
    
    
    def observation(self):
        pass
    
    def step(self,a):
        pass  
    
    def action(self,a):
        pass
    
    def reset(self):
        pass
    
    def render(self):
        pass
    
    def reward_output(self):
        pass
